# %%
from skimage import data

# %%
from skimage.color import rgb2gray
from numpy import r_

# %%
from io import BytesIO

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
DEFAULT_IMG_SIZE = (256, 256)

# %%
from skimage.transform import resize
import io
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy import fftpack
import IPython
import pandas as pd

from IPython.display import display, HTML

# %% [markdown]
# ### Compression performance measures functions

# %%
def calculate_mse(imageA, imageB):
    err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
    err /= float(imageA.shape[0] * imageA.shape[1])

    return err

def calculate_psnr(imageA, imageB):
    mse = np.mean( (imageA - imageB) ** 2 )
    if mse == 0:
        return 100
    PIXEL_MAX = 255.0
    
    return 10 * np.log10(PIXEL_MAX / np.sqrt(mse))


def print_measures(imageA, imageB):
    display(HTML('<h1> Measures </h1>'))
    
    display(HTML(pd.DataFrame([[calculate_mse(imageA, imageB),
                       calculate_psnr(imageA, imageB)]],
                       columns=["MSE", "PSNR"]).to_html()))

# %% [markdown]
# ### Load images

# %%
def get_image_and_resize(img_arr, size=DEFAULT_IMG_SIZE):
    image = Image.fromarray(img_arr)
    img_color = image.resize(size, 1)
    img_grey = img_color.convert('L')
    img = np.array(img_grey, dtype=np.float)

    return img

# %%
from skimage import img_as_ubyte, img_as_float

gray_images = {
    "cat": get_image_and_resize(data.chelsea()),
    "rocket": get_image_and_resize(data.rocket()),
    "moon": get_image_and_resize(data.moon()),
    "camera": get_image_and_resize(data.camera()),
    "coin": get_image_and_resize(data.coins()),
}

# %%
plt.imshow(gray_images['coin'], cmap=plt.cm.gray)

# %%
from numpy.linalg import svd
import numpy as np

# %% [markdown]
# # SVD

# %%
def compress_svd(img, k):
    """
    K - singular values
    """
    U, s, V = svd(img, full_matrices=False)
    reconst_matrix = np.dot(U[:, :k], np.dot(np.diag(s[:k]), (V[:k, :])))
    
    return reconst_matrix, s

# %%
print(gray_images['cat'].shape)
# Out:
# (256, 256)

# %% [markdown]
# ### Compress image and show result

# %%
def compress_svd_show(img_name, k, show_gray_image=True,
                      should_print_measures=True):
    """
    """
    image = gray_images[img_name]
    original_shape = image.shape
    
    reconst_img, s = compress_svd(image, k)
    
    compression_ratio = (original_shape[0] * original_shape[1]) / (
        k * (original_shape[0] + original_shape[1]) + k) 
        
    print("Compression ratio: {}".format(compression_ratio))
    if show_gray_image:
        fig, axes = plt.subplots(1, 2, figsize=(8, 5))
        axes[0].plot(s)
        
        axes[1].set_title("compression ratio {:.2f} %".format(compression_ratio))
        axes[1].imshow(reconst_img, cmap='gray')
        axes[1].axis('off')

        fig.tight_layout()
        
    if should_print_measures:
        print_measures(image, reconst_img)
    
    return reconst_img

# %%
from ipywidgets import interact, interactive, widgets

# %% [markdown]
# ### Interactively change k

# %%
interact(compress_svd_show, img_name=list(gray_images.keys()), k=(1, DEFAULT_IMG_SIZE[0]))
print("")
# Out:
# interactive(children=(Dropdown(description='img_name', options=('cat', 'rocket', 'moon', 'camera', 'coin'), va…

# %% [markdown]
# # DCT

# %%
def get_2d_dct(img):
    """ Get 2D Cosine Transform of Image
    """
    return fftpack.dct(fftpack.dct(img, norm='ortho', axis=0), norm='ortho', axis=1)

def get_2d_idct(coefficients):
    """ Get 2D Inverse Cosine Transform of Image
    """
    return fftpack.idct(fftpack.idct(coefficients, axis=0 , norm='ortho'), axis=1 , norm='ortho')

# %% [markdown]
# ### Blockwize dct / inverse dct function

# %%
def compress_dct(img):
    
    imsize = DEFAULT_IMG_SIZE
    dct = np.zeros(imsize)

    for i in r_[:imsize[0]:8]:
        for j in r_[:imsize[1]:8]:
            dct[i:(i+8),j:(j+8)] = get_2d_dct(img[i:(i+8),j:(j+8)] )
            
    return dct

# %%
def decompress_dct(img):
    
    imsize = DEFAULT_IMG_SIZE
    dct = np.zeros(imsize)

    for i in r_[:imsize[0]:8]:
        for j in r_[:imsize[1]:8]:
            dct[i:(i+8),j:(j+8)] = get_2d_idct(img[i:(i+8),j:(j+8)] )
            
    return dct

# %% [markdown]
# ### Filter function after applying DCT

# %%
def filter_by_number(dct, k):
    imsize = DEFAULT_IMG_SIZE
    dct_thresh = np.zeros(imsize)
    
    # Do 8x8 DCT on image (in-place)
    for i in r_[:imsize[0]:8]:
        for j in r_[:imsize[1]:8]:
            dummy_matrix = dct[i:(i+8),j:(j+8)]
            
            dummy_matrix[k:,:] = 0
            dummy_matrix[:,k:] = 0
            
            dct_thresh[i:(i+8),j:(j+8)] = dummy_matrix
    
    return dct_thresh

def filter_by_threshold(dct, thresh = 0.0012):
    imsize = DEFAULT_IMG_SIZE

    dct_thresh = dct * (abs(dct) > (thresh * np.max(dct)))

    nonzeros_count = np.sum( dct_thresh != 0.0 )
    
    compression_ratio = (original_shape[0] * original_shape[1]) / nonzeros_count
        
    percent_nonzeros =  nonzeros_count / (imsize[0] * imsize[1]*1.0)

    print("Keeping only %f%% of the DCT coefficients" % (percent_nonzeros*100.0))
    print("Compression ratio: {}".format(compression_ratio))
    
    return dct_thresh

# %% [markdown]
# ### Compress image and show result

# %%
def compress_dct_show(img_name, k, show_gray_image=True, should_print_measures=True):
    image = gray_images[img_name]
    dct_size = image.shape[0]
    dct = get_2d_dct(image)
    
    dct_copy = dct.copy()
    dct_copy[k:,:] = 0
    dct_copy[:,k:] = 0
    
    nonzeros_count = np.sum( dct_copy != 0.0 )
    compression_ratio = (image.shape[0] * image.shape[1]) / nonzeros_count
    print("Compression ratio: {}".format(compression_ratio))
    
    # Reconstructed image
    reconst_img = get_2d_idct(dct_copy)
    
    if show_gray_image:
        plt.figure()
        plt.imshow(reconst_img ,cmap='gray')
        plt.title("Reconstructed image" )
        
    if should_print_measures:
        print_measures(image, reconst_img)
    
    return reconst_img

# %%
dct = compress_dct(gray_images['cat'])
plt.figure()
plt.imshow(dct, cmap='gray', vmax = np.max(dct) * 0.01, vmin = 0)
plt.title( "8x8 DCTs of the image")
# Out:
# Text(0.5, 1.0, '8x8 DCTs of the image')

# %%
compress_dct_show('cat', 20, should_print_measures=False)
print("")
# Out:
# Compression ratio: 163.84

# %% [markdown]
# ### Interactively change k

# %%
interact(compress_dct_show, img_name=list(gray_images.keys()), k=(0, 256))
print("")
# Out:
# interactive(children=(Dropdown(description='img_name', options=('cat', 'rocket', 'moon', 'camera', 'coin'), va…

# %%
compress_dct_show('cat', 256)
# Out:
# Compression ratio: 1.0
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.851886e-28</td>
#       <td>162.727331</td>
#     </tr>
#   </tbody>
# </table>
# array([[125., 123., 123., ...,  33.,  31.,  30.],
#        [129., 125., 124., ...,  33.,  32.,  33.],
#        [131., 128., 127., ...,  33.,  33.,  35.],
#        ...,
#        [ 57.,  88.,  95., ..., 154., 153., 153.],
#        [ 97., 104.,  83., ..., 148., 149., 149.],
#        [106.,  92.,  87., ..., 142., 143., 144.]])

# %% [markdown]
# ## Wavelet is additional

# %%
import pywt

# %%
def compress_dwt(image, wavelet='haar'):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    titles = ['Approximation', ' Horizontal detail',
          'Vertical detail', 'Diagonal detail']
    
    # Now reconstruct and plot the original image
    reconstructed = pywt.idwt2(coeffs2, wavelet=wavelet)
    
    
    return coeffs2

def compress_dwt_show(img_name, k, wavelet='haar', show_gray_image=True, should_print_measures=True):
    img = gray_images[img_name]
    old_img = img
    
    for iteration in range(k):
        img, _ = compress_dwt(img, wavelet)
        
    if show_gray_image:    
        fig = plt.figure()
        plt.imshow(img, interpolation="nearest", cmap=plt.cm.gray)
    
    if should_print_measures:
        print_measures(old_img, np.resize(img, DEFAULT_IMG_SIZE))

# %%
interact(compress_dwt_show, img_name=list(gray_images.keys()), k=(0, 5), wavelet=pywt.wavelist())
# Out:
# interactive(children=(Dropdown(description='img_name', options=('cat', 'rocket', 'moon', 'camera', 'coin'), va…
# <function __main__.compress_dwt_show(img_name, k, wavelet='haar', show_gray_image=True, should_print_measures=True)>

# %%
def tell_img_size(array):
    image = Image.fromarray(array)
    image = image.convert("L")
    img_file = BytesIO()
    image.save(img_file, 'png')
    print(img_file.tell())

# %% [markdown]
# ## Compare SVD and DCT

# %% [markdown]
# ### coin img

# %%
# %%time
k = 150
compress_dct_show('coin', k, show_gray_image=False)
fig = plt.figure()
plt.imshow(gray_images['coin'], cmap=plt.cm.gray)
plt.title('Original Image')
# Out:
# Compression ratio: 2.9127111111111113
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>60.2913</td>
#       <td>15.164129</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 18.5 ms, sys: 2.05 ms, total: 20.5 ms
# Wall time: 18.7 ms

# %%
# %%time
k = 50
compress_svd_show('coin', k)
# Out:
# Compression ratio: 2.555009746588694
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>61.187808</td>
#       <td>15.132077</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 383 ms, sys: 10.1 ms, total: 393 ms
# Wall time: 98.9 ms

# %% [markdown]
# ### cat img

# %%
# %%time
k = 130
compress_dct_show('cat', k)
# Out:
# Compression ratio: 3.877869822485207
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>22.37022</td>
#       <td>17.317051</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 21.7 ms, sys: 2.77 ms, total: 24.4 ms
# Wall time: 22 ms

# %%
# %%time
k = 45
compress_svd_show('cat', k)
# Out:
# Compression ratio: 2.838899718431882
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>22.481233</td>
#       <td>17.306301</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 481 ms, sys: 14.1 ms, total: 495 ms
# Wall time: 126 ms

# %% [markdown]
# ## Comparing result images for paper (DCT)

# %%
k_s = [1, 5, 30, 60, 120, 160]
images = []
for k in k_s: 
    images.append(compress_dct_show('rocket', k, show_gray_image=False,))
# Out:
# Compression ratio: 65536.0
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>878.11109</td>
#       <td>9.347654</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 2621.44
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>375.033263</td>
#       <td>11.195053</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 72.81777777777778
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>134.87104</td>
#       <td>13.415808</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 18.204444444444444
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>67.712194</td>
#       <td>14.912067</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 4.551111111111111
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>34.127616</td>
#       <td>16.399872</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 2.56
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>20.965188</td>
#       <td>17.457908</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Rocket img

# %%
f, ax_arr = plt.subplots(2, 3, sharey=True)

for index, k in enumerate(k_s):
    ax_arr[index // 3, index - 3 * (index // 3)].imshow(images[index], cmap='gray')
    ax_arr[index // 3, index - 3 * (index // 3)].axis('off')
    ax_arr[index // 3, index - 3 * (index // 3)].set_title('K={}'.format(k))

# %% [markdown]
# ### comparing result images for paper (DCT)

# %%
k_s = [1, 5, 30, 60, 120, 160]
images = []
for k in k_s: 
    images.append(compress_svd_show('rocket', k, show_gray_image=False,))
# Out:
# Compression ratio: 127.75048732943469
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>283.547757</td>
#       <td>11.802271</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 25.55009746588694
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>79.229974</td>
#       <td>14.570954</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 4.258349577647823
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>17.537655</td>
#       <td>17.845544</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 2.1291747888239114
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4.958885</td>
#       <td>20.588482</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 1.0645873944119557
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.225475</td>
#       <td>27.299909</td>
#     </tr>
#   </tbody>
# </table>
# Compression ratio: 0.7984405458089668
# <h1> Measures </h1>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MSE</th>
#       <th>PSNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.035327</td>
#       <td>31.324894</td>
#     </tr>
#   </tbody>
# </table>

# %%
f, ax_arr = plt.subplots(2, 3, sharey=True, figsize=(9, 7))

for index, k in enumerate(k_s):
    ax_arr[index // 3, index - 3 * (index // 3)].imshow(images[index], cmap='gray')
    ax_arr[index // 3, index - 3 * (index // 3)].axis('off')
    ax_arr[index // 3, index - 3 * (index // 3)].set_title('K={}'.format(k))
